# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import librosa
import os
import random
import shutil
import webrtcvad

import soundfile as sf

# %%
training_dataset = "./dataset/Training"
testing_dataset = "./dataset/Testing"

train_image_dir = "./datasets_mel_uncut/train/images/"
train_label_dir = "./datasets_mel_uncut/train/labels/"

val_image_dir = "./datasets_mel_uncut/val/images/"
val_label_dir = "./datasets_mel_uncut/val/labels/"   

os.makedirs(train_image_dir, exist_ok=True)
os.makedirs(train_label_dir, exist_ok=True)
os.makedirs(val_image_dir, exist_ok=True)
os.makedirs(val_label_dir, exist_ok=True)

# %% [markdown]
# Testing set

# %%
# Loop through all language subdirectories in the dataset directory
for languages in os.listdir(testing_dataset):
    language_path = os.path.join(testing_dataset, languages)
    print(f"Processing language: {languages} at {language_path}")
    # Loop through all audio files in the language subdirectory
    for filename in os.listdir(language_path):
        file_path = os.path.join(language_path, filename)  # Construct the full path to the file
        print(f"Processing {filename}...")
        filename = filename[:-4]
        
        y, sr = librosa.load(file_path, sr=16000)  # Load the audio file (webrtcvad uses 16kHz)

        # Compute mel-spectrogram
        mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)  # Convert to decibel scale

        # Plot the mel-spectrogram
        plt.figure(figsize=(10, 6))
        plt.axis('off')  # Turn off axis
        librosa.display.specshow(mel_spec_db, sr=sr, x_axis='time', y_axis='mel')

        # Save the mel-spectrogram plot as an image
        output_dir = val_image_dir
        os.makedirs(output_dir, exist_ok=True)  # Ensure the output directory exists
        plt.savefig(f"{output_dir}/mel_spec_image_{filename}.png", transparent=True)
        plt.close()  # Close the plot to prevent display

        # Create label text file
        label_dir = val_label_dir
        os.makedirs(label_dir, exist_ok=True)
        label_file_path = os.path.join(label_dir, f"mel_spec_image_{filename}.txt")
        with open(label_file_path, "w") as label_file:
            language_to_id = {"En": 0, "Es": 1, "Fr": 2}
            label = language_to_id[languages]
            label_file.write(f"{label} 0.5 0.5 0.77 0.77\n")
# Out:
# Processing language: En at ./dataset/Testing\En
# Processing common_voice_en_40187707.wav...
# Processing common_voice_en_40190045.wav...
# Processing common_voice_en_40190086.wav...
# Processing common_voice_en_40190087.wav...
# Processing common_voice_en_40190092.wav...
# Processing common_voice_en_40190910.wav...
# Processing common_voice_en_40191944.wav...
# Processing common_voice_en_40191945.wav...
# Processing common_voice_en_40192478.wav...
# Processing common_voice_en_40192479.wav...
# Processing common_voice_en_40192487.wav...
# Processing common_voice_en_40193014.wav...
# Processing common_voice_en_40193015.wav...
# Processing common_voice_en_40193028.wav...
# Processing common_voice_en_40194948.wav...
# Processing common_voice_en_40197930.wav...
# Processing common_voice_en_40197931.wav...
# Processing common_voice_en_40200160.wav...
# Processing common_voice_en_40201445.wav...
# Processing common_voice_en_40201450.wav...
# Processing common_voice_en_40201451.wav...
# ...

# %% [markdown]
# Training set

# %%
# Loop through all language subdirectories in the dataset directory
for languages in os.listdir(training_dataset):
    if languages != "En":
        continue
    language_path = os.path.join(training_dataset, languages)
    print(f"Processing language: {languages} at {language_path}")
    # Loop through all audio files in the language subdirectory
    for filename in os.listdir(language_path):
        file_path = os.path.join(language_path, filename)  # Construct the full path to the file
        print(f"Processing {filename}...")
        filename = filename[:-4]
        
        y, sr = librosa.load(file_path, sr=16000)  # Load the audio file (webrtcvad uses 16kHz)

        # Compute mel-spectrogram
        mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)  # Convert to decibel scale

        # Plot the mel-spectrogram
        plt.figure(figsize=(10, 6))
        plt.axis('off')  # Turn off axis
        librosa.display.specshow(mel_spec_db, sr=sr, x_axis='time', y_axis='mel')

        # Save the mel-spectrogram plot as an image
        output_dir = train_image_dir
        os.makedirs(output_dir, exist_ok=True)  # Ensure the output directory exists
        plt.savefig(f"{output_dir}/mel_spec_image_{filename}.png", transparent=True)
        plt.close()  # Close the plot to prevent display

        # Create label text file
        label_dir = train_label_dir
        os.makedirs(label_dir, exist_ok=True)
        label_file_path = os.path.join(label_dir, f"mel_spec_image_{filename}.txt")
        with open(label_file_path, "w") as label_file:
            language_to_id = {"En": 0, "Es": 1, "Fr": 2}
            label = language_to_id[languages]
            label_file.write(f"{label} 0.5 0.5 0.77 0.77\n")
# Out:
# Processing language: En at ./dataset/Training\En
# Processing common_voice_en_41247202.wav...
# Processing common_voice_en_41247203.wav...
# Processing common_voice_en_41247259.wav...
# Processing common_voice_en_41247261.wav...
# Processing common_voice_en_41247311.wav...
# Processing common_voice_en_41247313.wav...
# Processing common_voice_en_41247339.wav...
# Processing common_voice_en_41247348.wav...
# Processing common_voice_en_41247374.wav...
# Processing common_voice_en_41247404.wav...
# Processing common_voice_en_41253075.wav...
# Processing common_voice_en_41254427.wav...
# Processing common_voice_en_41254430.wav...
# Processing common_voice_en_41254431.wav...
# Processing common_voice_en_41256752.wav...
# Processing common_voice_en_41256754.wav...
# Processing common_voice_en_41256755.wav...
# Processing common_voice_en_41259139.wav...
# Processing common_voice_en_41259459.wav...
# Processing common_voice_en_41259461.wav...
# Processing common_voice_en_41259462.wav...
# ...

# %%
# Loop through all language subdirectories in the dataset directory
for languages in os.listdir(training_dataset):
    if languages != "Es":
        continue
    language_path = os.path.join(training_dataset, languages)
    print(f"Processing language: {languages} at {language_path}")
    # Loop through all audio files in the language subdirectory
    for filename in os.listdir(language_path):
        file_path = os.path.join(language_path, filename)  # Construct the full path to the file
        print(f"Processing {filename}...")
        filename = filename[:-4]
        
        y, sr = librosa.load(file_path, sr=16000)  # Load the audio file (webrtcvad uses 16kHz)

        # Compute mel-spectrogram
        mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)  # Convert to decibel scale

        # Plot the mel-spectrogram
        plt.figure(figsize=(10, 6))
        plt.axis('off')  # Turn off axis
        librosa.display.specshow(mel_spec_db, sr=sr, x_axis='time', y_axis='mel')

        # Save the mel-spectrogram plot as an image
        output_dir = train_image_dir
        os.makedirs(output_dir, exist_ok=True)  # Ensure the output directory exists
        plt.savefig(f"{output_dir}/mel_spec_image_{filename}.png", transparent=True)
        plt.close()  # Close the plot to prevent display

        # Create label text file
        label_dir = train_label_dir
        os.makedirs(label_dir, exist_ok=True)
        label_file_path = os.path.join(label_dir, f"mel_spec_image_{filename}.txt")
        with open(label_file_path, "w") as label_file:
            language_to_id = {"En": 0, "Es": 1, "Fr": 2}
            label = language_to_id[languages]
            label_file.write(f"{label} 0.5 0.5 0.77 0.77\n")
# Out:
# Processing language: Es at ./dataset/Training\Es
# Processing common_voice_es_41243968.wav...
# Processing common_voice_es_41243998.wav...
# Processing common_voice_es_41244000.wav...
# Processing common_voice_es_41244003.wav...
# Processing common_voice_es_41248892.wav...
# Processing common_voice_es_41248893.wav...
# Processing common_voice_es_41248894.wav...
# Processing common_voice_es_41248896.wav...
# Processing common_voice_es_41248898.wav...
# Processing common_voice_es_41257115.wav...
# Processing common_voice_es_41257116.wav...
# Processing common_voice_es_41290206.wav...
# Processing common_voice_es_41290207.wav...
# Processing common_voice_es_41290209.wav...
# Processing common_voice_es_41290210.wav...
# Processing common_voice_es_41290211.wav...
# Processing common_voice_es_41290764.wav...
# Processing common_voice_es_41290765.wav...
# Processing common_voice_es_41290766.wav...
# Processing common_voice_es_41290767.wav...
# Processing common_voice_es_41290773.wav...
# ...

# %%
# Loop through all language subdirectories in the dataset directory
for languages in os.listdir(training_dataset):
    if languages != "Fr":
        continue
    language_path = os.path.join(training_dataset, languages)
    print(f"Processing language: {languages} at {language_path}")
    # Loop through all audio files in the language subdirectory
    for filename in os.listdir(language_path):
        file_path = os.path.join(language_path, filename)  # Construct the full path to the file
        print(f"Processing {filename}...")
        filename = filename[:-4]
        
        y, sr = librosa.load(file_path, sr=16000)  # Load the audio file (webrtcvad uses 16kHz)

        # Compute mel-spectrogram
        mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)  # Convert to decibel scale

        # Plot the mel-spectrogram
        plt.figure(figsize=(10, 6))
        plt.axis('off')  # Turn off axis
        librosa.display.specshow(mel_spec_db, sr=sr, x_axis='time', y_axis='mel')

        # Save the mel-spectrogram plot as an image
        output_dir = train_image_dir
        os.makedirs(output_dir, exist_ok=True)  # Ensure the output directory exists
        plt.savefig(f"{output_dir}/mel_spec_image_{filename}.png", transparent=True)
        plt.close()  # Close the plot to prevent display

        # Create label text file
        label_dir = train_label_dir
        os.makedirs(label_dir, exist_ok=True)
        label_file_path = os.path.join(label_dir, f"mel_spec_image_{filename}.txt")
        with open(label_file_path, "w") as label_file:
            language_to_id = {"En": 0, "Es": 1, "Fr": 2}
            label = language_to_id[languages]
            label_file.write(f"{label} 0.5 0.5 0.77 0.77\n")
# Out:
# Processing language: Fr at ./dataset/Training\Fr
# Processing common_voice_fr_41244049.wav...
# Processing common_voice_fr_41244050.wav...
# Processing common_voice_fr_41244051.wav...
# Processing common_voice_fr_41244053.wav...
# Processing common_voice_fr_41244091.wav...
# Processing common_voice_fr_41244127.wav...
# Processing common_voice_fr_41244129.wav...
# Processing common_voice_fr_41244131.wav...
# Processing common_voice_fr_41244134.wav...
# Processing common_voice_fr_41244164.wav...
# Processing common_voice_fr_41244165.wav...
# Processing common_voice_fr_41244166.wav...
# Processing common_voice_fr_41244168.wav...
# Processing common_voice_fr_41244169.wav...
# Processing common_voice_fr_41244192.wav...
# Processing common_voice_fr_41244194.wav...
# Processing common_voice_fr_41244199.wav...
# Processing common_voice_fr_41244240.wav...
# Processing common_voice_fr_41244242.wav...
# Processing common_voice_fr_41244243.wav...
# Processing common_voice_fr_41244244.wav...
# ...
